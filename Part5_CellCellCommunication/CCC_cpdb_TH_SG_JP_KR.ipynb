# %%
import pandas as pd
import sys
import os
import anndata

pd.set_option('display.max_columns', 100)
# Define our base directory for the analysis
os.chdir('/home/benjamaporn.sri/CCC_analysis')

# %%
cpdb_version = 'v5.0.0'
#Database locations
cpdb_target_dir = os.path.join('/home/benjamaporn.sri/CCC_analysis/db/test', cpdb_version)
cpdb_file_path = 'db/test/v5.0.0/cellphonedb.zip'

# %%
#TH Input files
TH_meta_file_path = '/mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202606/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_TH_merged_joined_20260701_meta_select.tsv'
TH_counts_file_path = '/mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202606/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_TH_merged_joined_20260701_anndata.h5ad'
TH_degs_file_path = '/mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202606/CCC/TH_UPdge_Blue_ref_All_celltypes_df_select.tsv'
TH_out_path = 'TH_AIDA/CCC/results/TH_withScore'

# %%
#SG Input files
SG_meta_file_path = '/mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_SG_merged_joined_20260707_meta_select.tsv'
SG_counts_file_path = '/mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_SG_merged_joined_20260707_anndata.h5ad'
SG_degs_file_path = '/mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/SG_UPdge_Blue_ref_All_celltypes_df_select.tsv'
SG_out_path = 'SG_AIDA/CCC/results/SG_withScore'

# %%
#JP Input files
JP_meta_file_path = '/mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_JP_merged_joined_20260721_meta_select.tsv'
JP_counts_file_path = '/mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_JP_merged_joined_20260721_anndata.h5ad'
JP_degs_file_path = '/mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/JP_UPdge_Red_ref_All_celltypes_df_select.tsv'
JP_out_path = 'JP_AIDA/CCC/results/JP_withScore'

# %%
#KR Input files
KR_meta_file_path = '/mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_KR_merged_joined_20260721_meta_select.tsv'
KR_counts_file_path = '/mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_KR_merged_joined_20260721_anndata.h5ad'
KR_degs_file_path = '/mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/KR_UPdge_Red_ref_All_celltypes_df_select.tsv'
KR_out_path = 'KR_AIDA/CCC/results/KR_withScore'

# %%
#Metadata
TH_metadata = pd.read_csv(TH_meta_file_path, sep = '\t')
SG_metadata = pd.read_csv(SG_meta_file_path, sep = '\t')
JP_metadata = pd.read_csv(JP_meta_file_path, sep = '\t')
KR_metadata = pd.read_csv(KR_meta_file_path, sep = '\t')

# %%
#Normalized count data per cell
TH_adata = anndata.read_h5ad(TH_counts_file_path)
SG_adata = anndata.read_h5ad(SG_counts_file_path)
JP_adata = anndata.read_h5ad(JP_counts_file_path)
KR_adata = anndata.read_h5ad(KR_counts_file_path)

# %%
#checked barcode matching between normalized count and metadata 
list(TH_adata.obs.index).sort() == list(TH_metadata['barcode_name']) \
    .sort()
list(SG_adata.obs.index).sort() == list(SG_metadata['barcode_name']) \
    .sort()
list(JP_adata.obs.index).sort() == list(JP_metadata['barcode_name']) \
    .sort()
list(KR_adata.obs.index).sort() == list(KR_metadata['barcode_name']) \
    .sort()
# Out:
# True

# %%
from cellphonedb.src.core.methods import cpdb_degs_analysis_method

TH_cpdb_results = cpdb_degs_analysis_method.call(
    cpdb_file_path = cpdb_file_path,                            
    meta_file_path = TH_meta_file_path,                            
    counts_file_path = TH_counts_file_path,                       
    degs_file_path = TH_degs_file_path,                           
    counts_data = 'hgnc_symbol',                               
    score_interactions = True,                                 
    threshold = 0.1,                                            
    result_precision = 3,                                       
    separator = '|',                                            
    debug = False,                                              
    output_path = TH_out_path,                                     
    output_suffix = None,                                      
    threads = 25
    )
# Out:
# [ ][CORE][05/08/26-00:05:44][INFO] [Cluster DEGs Analysis] Threshold:0.1 Precision:3
# Reading user files...
# WARNING: DEGs expects 2 columns and got 5. Dropping extra columns.
# The following user files were loaded successfully:
# /mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202606/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_TH_merged_joined_20260701_anndata.h5ad
# /mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202606/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_TH_merged_joined_20260701_meta_select.tsv
# /mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202606/CCC/TH_UPdge_Blue_ref_All_celltypes_df_select.tsv
# [ ][CORE][05/08/26-00:08:18][INFO] Running Real Analysis
# [ ][CORE][05/08/26-00:08:18][INFO] Running DEGs-based Analysis
# [ ][CORE][05/08/26-00:08:18][INFO] Building results
# [ ][CORE][05/08/26-00:08:19][INFO] Scoring interactions: Filtering genes per cell type..
# ...

# %%
from cellphonedb.src.core.methods import cpdb_degs_analysis_method

SG_cpdb_results = cpdb_degs_analysis_method.call(
    cpdb_file_path = cpdb_file_path,                            
    meta_file_path = SG_meta_file_path,                            
    counts_file_path = SG_counts_file_path,                       
    degs_file_path = SG_degs_file_path,                           
    counts_data = 'hgnc_symbol',                               
    score_interactions = True,                                 
    threshold = 0.1,                                            
    result_precision = 3,                                       
    separator = '|',                                            
    debug = False,                                              
    output_path = SG_out_path,                                     
    output_suffix = None,                                      
    threads = 25
    )
# Out:
# [ ][CORE][05/08/26-00:09:49][INFO] [Cluster DEGs Analysis] Threshold:0.1 Precision:3
# Reading user files...
# WARNING: DEGs expects 2 columns and got 5. Dropping extra columns.
# The following user files were loaded successfully:
# /mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_SG_merged_joined_20260707_anndata.h5ad
# /mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_SG_merged_joined_20260707_meta_select.tsv
# /mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/SG_UPdge_Blue_ref_All_celltypes_df_select.tsv
# [ ][CORE][05/08/26-00:17:37][INFO] Running Real Analysis
# [ ][CORE][05/08/26-00:17:37][INFO] Running DEGs-based Analysis
# [ ][CORE][05/08/26-00:17:38][INFO] Building results
# [ ][CORE][05/08/26-00:17:38][INFO] Scoring interactions: Filtering genes per cell type..
# ...

# %%
from cellphonedb.src.core.methods import cpdb_degs_analysis_method

JP_cpdb_results = cpdb_degs_analysis_method.call(
    cpdb_file_path = cpdb_file_path,                            
    meta_file_path = JP_meta_file_path,                            
    counts_file_path = JP_counts_file_path,                       
    degs_file_path = JP_degs_file_path,                           
    counts_data = 'hgnc_symbol',                               
    score_interactions = True,                                 
    threshold = 0.1,                                            
    result_precision = 3,                                       
    separator = '|',                                            
    debug = False,                                              
    output_path = JP_out_path,                                     
    output_suffix = None,                                      
    threads = 25
    )
# Out:
# [ ][CORE][05/08/26-00:19:20][INFO] [Cluster DEGs Analysis] Threshold:0.1 Precision:3
# Reading user files...
# WARNING: DEGs expects 2 columns and got 5. Dropping extra columns.
# The following user files were loaded successfully:
# /mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_JP_merged_joined_20260721_anndata.h5ad
# /mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_JP_merged_joined_20260721_meta_select.tsv
# /mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/JP_UPdge_Red_ref_All_celltypes_df_select.tsv
# [ ][CORE][05/08/26-00:24:16][INFO] Running Real Analysis
# [ ][CORE][05/08/26-00:24:16][INFO] Running DEGs-based Analysis
# [ ][CORE][05/08/26-00:24:17][INFO] Building results
# [ ][CORE][05/08/26-00:24:17][INFO] Scoring interactions: Filtering genes per cell type..
# ...

# %%
from cellphonedb.src.core.methods import cpdb_degs_analysis_method

KR_cpdb_results = cpdb_degs_analysis_method.call(
    cpdb_file_path = cpdb_file_path,                            
    meta_file_path = KR_meta_file_path,                            
    counts_file_path = KR_counts_file_path,                       
    degs_file_path = KR_degs_file_path,                           
    counts_data = 'hgnc_symbol',                               
    score_interactions = True,                                 
    threshold = 0.1,                                            
    result_precision = 3,                                       
    separator = '|',                                            
    debug = False,                                              
    output_path = KR_out_path,                                     
    output_suffix = None,                                      
    threads = 25
    )
# Out:
# [ ][CORE][05/08/26-00:25:54][INFO] [Cluster DEGs Analysis] Threshold:0.1 Precision:3
# Reading user files...
# WARNING: DEGs expects 2 columns and got 5. Dropping extra columns.
# The following user files were loaded successfully:
# /mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_KR_merged_joined_20260721_anndata.h5ad
# /mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/AIDA_Phase1_DataFreeze_v2_Step03_Seurat_Allcelltypes_KR_merged_joined_20260721_meta_select.tsv
# /mnt/icbs_shared_storage_general_2022/Benjamaporn/Analysis2026/Analysis202607/CCC/KR_UPdge_Red_ref_All_celltypes_df_select.tsv
# [ ][CORE][05/08/26-00:36:26][INFO] Running Real Analysis
# [ ][CORE][05/08/26-00:36:26][INFO] Running DEGs-based Analysis
# [ ][CORE][05/08/26-00:36:26][INFO] Building results
# [ ][CORE][05/08/26-00:36:27][INFO] Scoring interactions: Filtering genes per cell type..
# ...
